# %% [markdown]
# # uCIR Examples

# %%
void main(){
    print(0);
}

# %% [markdown]
# ```
# define void @main ()
# entry:
#   %1 = literal int 0
#   print int %1
# exit:
#   return
# ```

# %%
int n = 3;

int doubleMe (int x) {
    return x * x;
}

void main () {
    int v = n;
    v = doubleMe (v);
    assert v == n * n;
    return;
}

# %% [markdown]
# ```
# @n = global int 3
# @.str.0 = global string 'assertion_fail on 10:12'
#
# define int @doubleMe (int %1)
# entry:
#   %2 = alloc int
#   %x = alloc int
#   store int %1 %x
#   %3 = load int %x
#   %4 = load int %x
#   %5 = mul int %3 %4
#   store int %5 %2
#   jump label %exit
# exit:
#   %6 = load int %2
#   return int %6
#
# define void @main ()
# entry:
#   %v = alloc int
#   %1 = load int @n
#   store int %1 %v
#   %2 = load int %v
#   param int %2
#   %3 = call int @doubleMe
#   store int %3 %v
#   %4 = load int @n
#   %5 = load int @n
#   %6 = mul int %4 %5
#   %7 = load int %v
#   %8 = eq int %7 %6
#   cbranch %8 label %assert.true label %assert.false
# assert.false:
#   print string @.str.0
#   jump label %exit
# assert.true:
#   jump label %exit
# exit:
#   return
# ```

# %%
int main() {
  int x, y = 3;
  float z = 4.5;
  x = y + 5;
  z = (float)x;
  y = (int)z;
  return 0;
}

# %% [markdown]
# ```
# define int @main ()
# entry:
#   %1 = alloc int
#   %x = alloc int
#   %y = alloc int
#   %z = alloc float
#   %2 = literal int 3
#   store int %2 %y
#   %3 = literal float 4.5
#   store float %3 %z
#   %4 = literal int 5
#   %5 = load int %y
#   %6 = add int %5 %4
#   store int %6 %x
#   %7 = load int %x
#   %8 = sitofp %7
#   store float %8 %z
#   %9 = load float %z
#   %10 = fptosi %9
#   store int %10 %y
#   %11 = literal int 0
#   store int %11 %1
#   jump label %exit
# exit:
#   %12 = load int %1
#   return int %12
# ```

# %%
void main(){
  int i, j;
  int *r;
  int y[5];
  r = &y[j];
  i = y[j];
  y[i] = i + j;
  return;
}

# %% [markdown]
# ```
# define void @main ()
# entry:
#   %i = alloc int
#   %j = alloc int
#   %r = alloc int*
#   %y = alloc int[5]
#   %1 = load int %j
#   %2 = elem int %y %1
#   %r = get int* %2
#   %3 = load int %j
#   %4 = elem int %y %3
#   %5 = load int* %4
#   store int %5 %i
#   %6 = load int %i
#   %7 = load int %j
#   %8 = add int %6 %7
#   %9 = load int %i
#   %10 = elem int %y %9
#   store int* %8 %10
#   jump label %exit
# exit:
#   return
# ```

# %%
int main () {
    int x = 2, y, z;
    y = ++x;
    z = x++;
    assert x == 4 && y == z;
    return 1;
}

# %% [markdown]
# ```
# define int @main ()
# entry:
#   %1 = alloc int
#   %x = alloc int
#   %y = alloc int
#   %z = alloc int
#   %2 = literal int 2
#   store int %2 %x
#   %3 = load int %x
#   %4 = literal int 1
#   %5 = add int %3 %4
#   store int %5 %x
#   store int %5 %y
#   %6 = load int %x
#   %7 = literal int 1
#   %8 = add int %6 %7
#   store int %8 %x
#   store int %6 %z
#   %9 = literal int 4
#   %10 = load int %x
#   %11 = eq int %10 %9
#   %12 = load int %y
#   %13 = load int %z
#   %14 = eq int %12 %13
#   %15 = and bool %11 %14
#   cbranch %15 label %assert.true label %assert.false
# assert.false:
#   print string @.str.0
#   jump label %exit
# assert.true:
#   %16 = literal int 1
#   store int %16 %1
#   jump label %exit
# exit:
#   %17 = load int %1
#   return int %17
# ```

# %%
int main () {
    int i, j;
    i = 1;
    j = 2;
    for (int k=1; k<10; k++)
        i += j * k;
    assert i == 91;
    return 0;
}

# %% [markdown]
# ```
# @.str.0 = global string 'assertion_fail on 7:12'
#
# define int @main ()
# entry:
#   %1 = alloc int
#   %i = alloc int
#   %j = alloc int
#   %k.2 = alloc int
#   %2 = literal int 1
#   store int %2 %i
#   %3 = literal int 2
#   store int %3 %j
#   %4 = literal int 1
#   store int %4 %k.2
#   jump label %for.cond
# for.cond:
#   %5 = literal int 10
#   %6 = load int %k.2
#   %7 = lt int %6 %5
#   cbranch %7 label %for.body label %for.end
# for.body:
#   %8 = load int %j
#   %9 = load int %k.2
#   %10 = mul int %8 %9
#   %11 = load int %i
#   %12 = add int %11 %10
#   store int %12 %i
#   jump label %for.inc
# for.inc:
#   %13 = load int %k.2
#   %14 = literal int 1
#   %15 = add int %13 %14
#   store int %15 %k.2
#   jump label %for.cond
# for.end:
#   %16 = literal int 91
#   %17 = load int %i
#   %18 = eq int %17 %16
#   cbranch %18 label %assert.true label %assert.false
# assert.false:
#   print string @.str.0
#   jump label %exit
# assert.true:
#   %19 = literal int 0
#   store int %19 %1
#   jump label %exit
# exit:
#   %20 = load int %1
#   return int %20
# ```

# %%
int main () {
    float f[] = {1.0, 2.5, 5.0};
    char s[] = "xpto";
    int v[][] = {{1,3}, {2,6}, {3,9}};
    int i = 1, j = 0;
    print("Isto é um teste:", s[j+2]);
    print(f[i], v[i][j]);
    return 0;
}

# %% [markdown]
# ```
# @.const_f.0 = global float[3] [1.0, 2.5, 5.0]
# @.str.1 = global string 'xpto'
# @.const_v.2 = global int[3][2] [[1, 3], [2, 6], [3, 9]]
# @.str.3 = global string 'Isto é um teste:'
#
# define int @main ()
# entry:
#   %1 = alloc int
#   %f = alloc float[3]
#   %s = alloc char[4]
#   %v = alloc int[3][2]
#   %i = alloc int
#   %j = alloc int
#   store float[3] @.const_f.0 %f
#   store char[4] @.str.1 %s
#   store int[3][2] @.const_v.2 %v
#   %2 = literal int 1
#   store int %2 %i
#   %3 = literal int 0
#   store int %3 %j
#   print string @.str.3
#   %4 = literal int 2
#   %5 = load int %j
#   %6 = add int %5 %4
#   %7 = elem char %s %6
#   %8 = load char* %7
#   print char %8
#   %9 = load int %i
#   %10 = elem float %f %9
#   %11 = load float* %10
#   print float %11
#   %12 = literal int 2
#   %13 = load int %i
#   %14 = mul int %12 %13
#   %15 = load int %j
#   %16 = add int %14 %15
#   %17 = elem int %v %16
#   %18 = load int* %17
#   print int %18
#   %19 = literal int 0
#   store int %19 %1
#   jump label %exit
# exit:
#   %20 = load int %1
#   return int %20
# ```

# %%
/* Bubble sort code */

int main() {
    int v[100];
    int n, c, d, swap;
    print("Enter number of elements: ");
    read(n);
    print("Enter ", n, " integers: ");
    for (c = 0; c < n; c++)
        read(v[c]);
    for (c = 0; c < n-1; c++)
        for (d = 0; d < n-c-1; d++)
            if (v[d] > v[d+1]) {
                swap = v[d];
                v[d] = v[d+1];
                v[d+1] = swap;
            }
    print("Sorted list in ascending order: ");
    for (c = 0; c < n; c++)
        print(v[c], " ");
    return 0;
}

# %% [markdown]
# ```
# @.str.0 = global string 'Enter number of elements: '
# @.str.1 = global string 'Enter '
# @.str.2 = global string ' integers: '
# @.str.3 = global string 'Sorted list in ascending order: '
# @.str.4 = global string ' '
#
# define int @main ()
# entry:
#   %1 = alloc int
#   %v = alloc int[100]
#   %n = alloc int
#   %c = alloc int
#   %d = alloc int
#   %swap = alloc int
#   print string @.str.0
#   %n = read int
#   print string @.str.1
#   %2 = load int %n
#   print int %2
#   print string @.str.2
#   %3 = literal int 0
#   store int %3 %c
#   jump label %for.cond
# for.cond:
#   %4 = load int %c
#   %5 = load int %n
#   %6 = lt int %4 %5
#   cbranch %6 label %for.body label %for.end
# for.body:
#   %7 = load int %c
#   %8 = elem int %v %7
#   %8 = read int*
#   jump label %for.inc
# for.inc:
#   %9 = load int %c
#   %10 = literal int 1
#   %11 = add int %9 %10
#   store int %11 %c
#   jump label %for.cond
# for.end:
#   %12 = literal int 0
#   store int %12 %c
#   jump label %for.cond.1
# for.cond.1:
#   %13 = literal int 1
#   %14 = load int %n
#   %15 = sub int %14 %13
#   %16 = load int %c
#   %17 = lt int %16 %15
#   cbranch %17 label %for.body.1 label %for.end.1
# for.body.1:
#   %18 = literal int 0
#   store int %18 %d
#   jump label %for.cond.2
# for.cond.2:
#   %19 = load int %n
#   %20 = load int %c
#   %21 = sub int %19 %20
#   %22 = literal int 1
#   %23 = sub int %21 %22
#   %24 = load int %d
#   %25 = lt int %24 %23
#   cbranch %25 label %for.body.2 label %for.end.2
# for.body.2:
#   %26 = load int %d
#   %27 = elem int %v %26
#   %28 = literal int 1
#   %29 = load int %d
#   %30 = add int %29 %28
#   %31 = elem int %v %30
#   %32 = load int* %27
#   %33 = load int* %31
#   %34 = gt int %32 %33
#   cbranch %34 label %if.then label %if.end
# if.then:
#   %35 = load int %d
#   %36 = elem int %v %35
#   %37 = load int* %36
#   store int %37 %swap
#   %38 = literal int 1
#   %39 = load int %d
#   %40 = add int %39 %38
#   %41 = elem int %v %40
#   %42 = load int* %41
#   %43 = load int %d
#   %44 = elem int %v %43
#   store int* %42 %44
#   %45 = load int %swap
#   %46 = literal int 1
#   %47 = load int %d
#   %48 = add int %47 %46
#   %49 = elem int %v %48
#   store int* %45 %49
#   jump label %if.end
# if.end:
#   jump label %for.inc.2
# for.inc.2:
#   %50 = load int %d
#   %51 = literal int 1
#   %52 = add int %50 %51
#   store int %52 %d
#   jump label %for.cond.2
# for.end.2:
#   jump label %for.inc.1
# for.inc.1:
#   %53 = load int %c
#   %54 = literal int 1
#   %55 = add int %53 %54
#   store int %55 %c
#   jump label %for.cond.1
# for.end.1:
#   print string @.str.3
#   %56 = literal int 0
#   store int %56 %c
#   jump label %for.cond.3
# for.cond.3:
#   %57 = load int %c
#   %58 = load int %n
#   %59 = lt int %57 %58
#   cbranch %59 label %for.body.3 label %for.end.3
# for.body.3:
#   %60 = load int %c
#   %61 = elem int %v %60
#   %62 = load int* %61
#   print int %62
#   print string @.str.4
#   jump label %for.inc.3
# for.inc.3:
#   %63 = load int %c
#   %64 = literal int 1
#   %65 = add int %63 %64
#   store int %65 %c
#   jump label %for.cond.3
# for.end.3:
#   %66 = literal int 0
#   store int %66 %1
#   jump label %exit
# exit:
#   %67 = load int %1
#   return int %67
# ```

# %%
int (*operation)(int x, int y);

int add(int x, int y) {
    return x + y;
}

int subtract(int x, int y) {
    return x - y;
}

int main() {
   int  foo, bar;
   read(foo, bar);
   operation = &add;
   print(foo, " + ", bar, " = ", operation(foo, bar), ", ");
   operation = &subtract;
   print(foo, " - ", bar, " = ", operation(foo, bar));
   return 0;
}

# %% [markdown]
# ```
# @operation = global int* ['int', 'int']
# @.str.0 = global string ' + '
# @.str.1 = global string ' = '
# @.str.2 = global string ', '
# @.str.3 = global string ' - '
# @.str.4 = global string ' = '
#
# define int @add (int %1, int %2)
# entry:
#   %3 = alloc int
#   %x = alloc int
#   %y = alloc int
#   store int %1 %x
#   store int %2 %y
#   %4 = load int %x
#   %5 = load int %y
#   %6 = add int %4 %5
#   store int %6 %3
#   jump label %exit
# exit:
#   %7 = load int %3
#   return int %7
#
# define int @subtract (int %1, int %2)
# entry:
#   %3 = alloc int
#   %x = alloc int
#   %y = alloc int
#   store int %1 %x
#   store int %2 %y
#   %4 = load int %x
#   %5 = load int %y
#   %6 = sub int %4 %5
#   store int %6 %3
#   jump label %exit
# exit:
#   %7 = load int %3
#   return int %7
#
# define int @main ()
# entry:
#   %1 = alloc int
#   %foo = alloc int
#   %bar = alloc int
#   %foo = read int
#   %bar = read int
#   @operation = get int* @add
#   %2 = load int %foo
#   print int %2
#   print string @.str.0
#   %3 = load int %bar
#   print int %3
#   print string @.str.1
#   %4 = load int %foo
#   %5 = load int %bar
#   param int %4
#   param int %5
#   %6 = load int* @operation
#   %7 = call int %6
#   print int %7
#   print string @.str.2
#   @operation = get int* @subtract
#   %8 = load int %foo
#   print int %8
#   print string @.str.3
#   %9 = load int %bar
#   print int %9
#   print string @.str.4
#   %10 = load int %foo
#   %11 = load int %bar
#   param int %10
#   param int %11
#   %12 = load int* @operation
#   %13 = call int %12
#   print int %13
#   %14 = literal int 0
#   store int %14 %1
#   jump label %exit
# exit:
#   %15 = load int %1
#   return int %15
# ```
