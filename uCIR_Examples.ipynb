# %% [markdown]
# # uCIR Examples

# %%
int n = 3;

int doubleMe (int x) {
    return x * x;
}

void main () {
    int v = n;
    v = doubleMe (v);
    assert v == n * n;
    return;
}

# %% [markdown]
# ```
# global_int @n 3
# global_string @.str.0 'assertion_fail on 10:12'
#
# define @doubleMe
# entry:
#   alloc_int %x
#   store_int %0 %x
#   load_int %x %2
#   load_int %x %3
#   mul_int %2 %3 %4
#   store_int %4 %1
#   jump label %exit
# exit:
#   load_int %1 %5
#   return_int %5
#
# define @main
# entry:
#   alloc_int %v
#   load_int @n %1
#   store_int %1 %v
#   load_int %v %2
#   param_int %2
#   call @doubleMe %3
#   store_int %3 %v
#   load_int @n %4
#   load_int @n %5
#   mul_int %4 %5 %6
#   load_int %v %7
#   eq_int %7 %6 %8
#   cbranch %8 label %assert.true label %assert.false
# assert.false:
#   print_string @.str.0
#   jump label %exit
# assert.true:
#   jump label %exit
# exit:
#   return_void
# ```

# %%
int main() {
  int x, y = 3;
  float z = 4.5;
  x = y + 5;
  z = (float)x;
  y = (int)z;
  return 0;
}

# %% [markdown]
# ```
# define @main
# entry:
#   alloc_int %x
#   alloc_int %y
#   alloc_float %z
#   literal_int 3 %1
#   store_int %1 %y
#   literal_float 4.5 %2
#   store_float %2 %z
#   literal_int 5 %3
#   load_int %y %4
#   add_int %4 %3 %5
#   store_int %5 %x
#   load_int %x %6
#   sitofp %6 %7
#   store_float %7 %z
#   load_float %z %8
#   fptosi %8 %9
#   store_int %9 %y
#   literal_int 0 %10
#   store_int %10 %0
#   jump label %exit
# exit:
#   load_int %0 %11
#   return_int %11
# ```

# %%
void main(){
  int i, j;
  int *r;
  int y[5];
  r = &y[j];
  i = y[j];
  y[i] = i + j;
  return;
}

# %% [markdown]
# ```
# define @main
# entry:
#   alloc_int %i
#   alloc_int %j
#   alloc_int_* %r
#   alloc_int_5 %y
#   load_int %j %1
#   elem_int %y %1 %2
#   get_int_* %2 %r
#   load_int %j %3
#   elem_int %y %3 %4
#   load_int_* %4 %5
#   store_int %5 %i
#   load_int %i %6
#   load_int %j %7
#   add_int %6 %7 %8
#   load_int %i %9
#   elem_int %y %9 %10
#   store_int_* %8 %10
#   jump label %exit
# exit:
#   return_void
# ```

# %%
int main () {
    int x = 2, y, z;
    y = ++x;
    z = x++;
    assert x == 4 && y == z;
    return 1;
}

# %% [markdown]
# ```
# global_string @.str.0 'assertion_fail on 5:12'
#
# define @main
# entry:
#   alloc_int %x
#   alloc_int %y
#   alloc_int %z
#   literal_int 2 %1
#   store_int %1 %x
#   load_int %x %2
#   literal_int 1 %3
#   add_int %2 %3 %4
#   store_int %4 %x
#   store_int %4 %y
#   load_int %x %5
#   literal_int 1 %6
#   add_int %5 %6 %7
#   store_int %7 %x
#   store_int %5 %z
#   literal_int 4 %8
#   load_int %x %9
#   eq_int %9 %8 %10
#   load_int %y %11
#   load_int %z %12
#   eq_int %11 %12 %13
#   and_bool %10 %13 %14
#   cbranch %14 label %assert.true label %assert.false
# assert.false:
#   print_string @.str.0
#   jump label %exit
# assert.true:
#   literal_int 1 %15
#   store_int %15 %0
#   jump label %exit
# exit:
#   load_int %0 %16
#   return_int %16
# ```

# %%
int main () {
    int i, j;
    i = 1;
    j = 2;
    for (int k=1; k<10; k++)
        i += j * k;
    assert i == 91;
    return 0;
}

# %% [markdown]
# ```
# global_string @.str.0 'assertion_fail on 7:12'
#
# define @main
# entry:
#   alloc_int %i
#   alloc_int %j
#   alloc_int %k
#   literal_int 1 %1
#   store_int %1 %i
#   literal_int 2 %2
#   store_int %2 %j
#   literal_int 1 %3
#   store_int %3 %k
# for.cond:
#   literal_int 10 %4
#   load_int %k %5
#   lt_int %5 %4 %6
#   cbranch %6 label %for.body label %for.end
# for.body:
#   load_int %j %7
#   load_int %k %8
#   mul_int %7 %8 %9
#   load_int %i %10
#   add_int %9 %10 %11
#   store_int %11 %i
#   jump label %for.inc
# for.inc:
#   load_int %k %12
#   literal_int 1 %13
#   add_int %12 %13 %14
#   store_int %14 %k
#   jump label %for.cond
# for.end:
#   literal_int 91 %15
#   load_int %i %16
#   eq_int %16 %15 %17
#   cbranch %17 label %assert.true label %assert.false
# assert.false:
#   print_string @.str.0
#   jump label %exit
# assert.true:
#   literal_int 0 %18
#   store_int %18 %0
#   jump label %exit
# exit:
#   load_int %0 %19
#   return_int %19
# ```

# %%
int main () {
    float f[] = {1.0, 2.5, 5.0};
    char s[] = "xpto";
    int v[][] = {{1,3}, {2,6}, {3,9}};
    int i = 1, j = 0;
    print("Isto é um teste:", s[j+2]);
    print(f[i], v[i][j]);
    return 0;
}

# %% [markdown]
# ```
# global_float_3 @.const_f.0 [1.0, 2.5, 5.0]
# global_string @.str.1 'xpto'
# global_int_3_2 @.const_v.2 [[1, 3], [2, 6], [3, 9]]
# global_string @.str.3 'Isto é um teste:'
#
# define @main
# entry:
#   alloc_float_3 %f
#   alloc_char_4 %s
#   alloc_int_3_2 %v
#   alloc_int %i
#   alloc_int %j
#   store_float_3 @.const_f.0 %f
#   store_char_4 @.str.1 %s
#   store_int_3_2 @.const_v.2 %v
#   literal_int 1 %1
#   store_int %1 %i
#   literal_int 0 %2
#   store_int %2 %j
#   print_string @.str.3
#   literal_int 2 %3
#   load_int %j %4
#   add_int %4 %3 %5
#   elem_char %s %5 %6
#   load_char_* %6 %7
#   print_char %7
#   load_int %i %8
#   elem_float %f %8 %9
#   load_float_* %9 %10
#   print_float %10
#   literal_int 2 %11
#   load_int %i %12
#   mul_int %11 %12 %13
#   load_int %j %14
#   add_int %13 %14 %15
#   elem_int %v %15 %16
#   load_int_* %16 %17
#   print_int %17
#   literal_int 0 %18
#   store_int %18 %0
#   jump label %exit
# exit:
#   load_int %0 %19
#   return_int %19
# ```

# %%
/* Bubble sort code */

int main() {
    int v[100];
    int n, c, d, swap;
    print("Enter number of elements: ");
    read(n);
    print("Enter ", n, " integers: ");
    for (c = 0; c < n; c++)
        read(v[c]);
    for (c = 0; c < n-1; c++)
        for (d = 0; d < n-c-1; d++)
            if (v[d] > v[d+1]) {
                swap = v[d];
                v[d] = v[d+1];
                v[d+1] = swap;
            }
    print("Sorted list in ascending order: ");
    for (c = 0; c < n; c++)
        print(v[c], " ");
    return 0;
}

# %% [markdown]
# ```
# global_string @.str.0 'Enter number of elements: '
# global_string @.str.1 'Enter '
# global_string @.str.2 ' integers: '
# global_string @.str.3 'Sorted list in ascending order: '
# global_string @.str.4 ' '
#
# define @main
# entry:
#   alloc_int_100 %v
#   alloc_int %n
#   alloc_int %c
#   alloc_int %d
#   alloc_int %swap
#   print_string @.str.0
#   read_int %1
#   store_int %1 %n
#   print_string @.str.1
#   load_int %n %2
#   print_int %2
#   print_string @.str.2
#   literal_int 0 %3
#   store_int %3 %c
# for.cond:
#   load_int %c %4
#   load_int %n %5
#   lt_int %4 %5 %6
#   cbranch %6 label %for.body label %for.end
# for.body:
#   load_int %c %7
#   elem_int %v %7 %8
#   read_int %9
#   store_int_* %9 %8
#   jump label %for.inc
# for.inc:
#   load_int %c %10
#   literal_int 1 %11
#   add_int %10 %11 %12
#   store_int %12 %c
#   jump label %for.cond
# for.end:
#   literal_int 0 %13
#   store_int %13 %c
# for.cond.1:
#   literal_int 1 %14
#   load_int %n %15
#   sub_int %15 %14 %16
#   load_int %c %17
#   lt_int %17 %16 %18
#   cbranch %18 label %for.body.1 label %for.end.1
# for.body.1:
#   literal_int 0 %19
#   store_int %19 %d
# for.cond.2:
#   load_int %n %20
#   load_int %c %21
#   sub_int %20 %21 %22
#   literal_int 1 %23
#   sub_int %22 %23 %24
#   load_int %d %25
#   lt_int %25 %24 %26
#   cbranch %26 label %for.body.2 label %for.end.2
# for.body.2:
#   load_int %d %27
#   elem_int %v %27 %28
#   literal_int 1 %29
#   load_int %d %30
#   add_int %30 %29 %31
#   elem_int %v %31 %32
#   load_int_* %28 %33
#   load_int_* %32 %34
#   gt_int %33 %34 %35
#   cbranch %35 label %if.then label %if.end
# if.then:
#   load_int %d %36
#   elem_int %v %36 %37
#   load_int_* %37 %38
#   store_int %38 %swap
#   literal_int 1 %39
#   load_int %d %40
#   add_int %40 %39 %41
#   elem_int %v %41 %42
#   load_int_* %42 %43
#   load_int %d %44
#   elem_int %v %44 %45
#   store_int_* %43 %45
#   load_int %swap %46
#   literal_int 1 %47
#   load_int %d %48
#   add_int %48 %47 %49
#   elem_int %v %49 %50
#   store_int_* %46 %50
#   jump label %if.end
# if.end:
#   jump label %for.inc.2
# for.inc.2:
#   load_int %d %51
#   literal_int 1 %52
#   add_int %51 %52 %53
#   store_int %53 %d
#   jump label %for.cond.2
# for.end.2:
#   jump label %for.inc.1
# for.inc.1:
#   load_int %c %54
#   literal_int 1 %55
#   add_int %54 %55 %56
#   store_int %56 %c
#   jump label %for.cond.1
# for.end.1:
#   print_string @.str.3
#   literal_int 0 %57
#   store_int %57 %c
# for.cond.3:
#   load_int %c %58
#   load_int %n %59
#   lt_int %58 %59 %60
#   cbranch %60 label %for.body.3 label %for.end.3
# for.body.3:
#   load_int %c %61
#   elem_int %v %61 %62
#   load_int_* %62 %63
#   print_int %63
#   print_string @.str.4
#   jump label %for.inc.3
# for.inc.3:
#   load_int %c %64
#   literal_int 1 %65
#   add_int %64 %65 %66
#   store_int %66 %c
#   jump label %for.cond.3
# for.end.3:
#   literal_int 0 %67
#   store_int %67 %0
#   jump label %exit
# exit:
#   load_int %0 %68
#   return_int %68
# ```

# %%
int (*operation)(int x, int y);

int add(int x, int y) {
    return x + y;
}

int subtract(int x, int y) {
    return x - y;
}

int main() {
   int  foo, bar;
   read(foo, bar);
   operation = &add;
   print(foo, " + ", bar, " = ", operation(foo, bar), ", ");
   operation = &subtract;
   print(foo, " - ", bar, " = ", operation(foo, bar));
   return 0;
}

# %% [markdown]
# ```
# global_int_* @operation
# global_string @.str.0 ' + '
# global_string @.str.1 ' = '
# global_string @.str.2 ', '
# global_string @.str.3 ' - '
# global_string @.str.4 ' = '
#
# define @add
# entry:
#   alloc_int %x
#   alloc_int %y
#   store_int %0 %x
#   store_int %1 %y
#   load_int %x %3
#   load_int %y %4
#   add_int %3 %4 %5
#   store_int %5 %2
#   jump label %exit
# exit:
#   load_int %2 %6
#   return_int %6
#
# define @subtract
# entry:
#   alloc_int %x
#   alloc_int %y
#   store_int %0 %x
#   store_int %1 %y
#   load_int %x %3
#   load_int %y %4
#   sub_int %3 %4 %5
#   store_int %5 %2
#   jump label %exit
# exit:
#   load_int %2 %6
#   return_int %6
#
# define @main
# entry:
#   alloc_int %foo
#   alloc_int %bar
#   read_int %1
#   store_int %1 %foo
#   read_int %2
#   store_int %2 %bar
#   get_int_* @add @operation
#   load_int %foo %3
#   print_int %3
#   print_string @.str.0
#   load_int %bar %4
#   print_int %4
#   print_string @.str.1
#   load_int %foo %5
#   load_int %bar %6
#   param_int %5
#   param_int %6
#   load_int_* @operation %7
#   call %7 %8
#   print_int %8
#   print_string @.str.2
#   get_int_* @subtract @operation
#   load_int %foo %9
#   print_int %9
#   print_string @.str.3
#   load_int %bar %10
#   print_int %10
#   print_string @.str.4
#   load_int %foo %11
#   load_int %bar %12
#   param_int %11
#   param_int %12
#   load_int_* @operation %13
#   call %13 %14
#   print_int %14
#   literal_int 0 %15
#   store_int %15 %0
#   jump label %exit
# exit:
#   load_int %0 %16
#   return_int %16
# ```
